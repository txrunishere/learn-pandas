# %%
import pandas as pd
import numpy as np

# %%
data = {
  'A': [1, 2, 3, 4, 5],
  'B': [10, 20, 30, 40, 50],
  'C': [100, 200, 300, 400, 500]
}
df = pd.DataFrame(data)

# %%
df.size

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df['A'] + 10

# %%
def square(x):
  return x**2

# %%
df['A'].apply(square)
